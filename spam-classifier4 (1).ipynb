# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd

# Specify the encoding parameter
df = pd.read_csv('spam.csv', encoding='latin1')

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 1374  spam  500 New Mobiles from 2004, MUST GO! Txt: NOKIA...        NaN
# 1130   ham                          Howz pain?hope u r fine..        NaN
# 1468  spam  Hi its LUCY Hubby at meetins all day Fri & I w...        NaN
# 4844   ham                  Missing you too.pray inshah allah        NaN
# 3396   ham                       Heehee that was so funny tho        NaN
#
#      Unnamed: 3 Unnamed: 4
# 1374        NaN        NaN
# 1130        NaN        NaN
# 1468        NaN        NaN
# 4844        NaN        NaN
# 3396        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 2248  ham                    will you like to be spoiled? :)
# 2648  ham  Hi, can i please get a  &lt;#&gt;  dollar loan...
# 74    ham                               U can call me now...
# 1557  ham                                     Wat r u doing?
# 1067  ham  Meeting u is my work. . . Tel me when shall i ...

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)

# %%
df.sample(5)
# Out:
#      target                                               text
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 1892   spam  CALL 09090900040 & LISTEN TO EXTREME DIRTY LIV...
# 4129    ham                 And by when you're done I mean now
# 832    spam  Dear Voucher Holder, To claim this weeks offer...
# 1228   spam  FREE entry into our å£250 weekly comp just sen...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df = df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (5169, 2)

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct="%0.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x29820f435d0>,
#   <matplotlib.patches.Wedge at 0x29821025810>],
#  [Text(-1.0144997251399075, 0.4251944351600247, 'ham'),
#   Text(1.014499764949479, -0.4251943401757036, 'spam')],
#  [Text(-0.5533634864399495, 0.23192423736001344, '87.37'),
#   Text(0.5533635081542612, -0.23192418555038377, '12.63')])

# %%
import nltk

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\100956383\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
df['num_words'] = df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
df['num_sentences'] = df['text'].apply(lambda x:(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words                                      num_sentences
# 0         24  [Go until jurong point, crazy.., Available onl...
# 1          8                   [Ok lar..., Joking wif u oni...]
# 2         37  [Free entry in 2 a wkly comp to win FA Cup fin...
# 3         13  [U dun say so early hor... U c already then sa...
# 4         15  [Nah I don't think he goes to usf, he lives ar...

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
correlation_matrix = df[numeric_columns].corr()

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words
# count     5169.000000  5169.000000
# mean        78.977945    18.455794
# std         58.236293    13.324758
# min          2.000000     1.000000
# 25%         36.000000     9.000000
# 50%         60.000000    15.000000
# 75%        117.000000    26.000000
# max        910.000000   220.000000

# %%
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words
# count     4516.000000  4516.000000
# mean        70.459256    17.123782
# std         56.358207    13.493970
# min          2.000000     1.000000
# 25%         34.000000     8.000000
# 50%         52.000000    13.000000
# 75%         90.000000    22.000000
# max        910.000000   220.000000

# %%
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words
# count      653.000000  653.000000
# mean       137.891271   27.667688
# std         30.137753    7.008418
# min         13.000000    2.000000
# 25%        132.000000   25.000000
# 50%        149.000000   29.000000
# 75%        157.000000   32.000000
# max        224.000000   46.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color='yellow')
# Out:
# C:\Users\100956383\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\100956383\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'],color='yellow')
# Out:
# C:\Users\100956383\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\100956383\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')
# Out:
# C:\Users\100956383\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\100956383\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, )
plt.title('Correlation Matrix')
plt.show()

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    text = y[:]
    y.clear()


    for i in text:
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\100956383\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# Get the English stopwords
english_stopwords = stopwords.words('english')

# Print the stopwords
print(english_stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\100956383\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import string
from nltk.stem import PorterStemmer

def transform_text(text):
    ps = PorterStemmer()
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

transformed_text = transform_text('I always loved to learn Python and Machine Learning.')
print(transformed_text)
# Out:
# i alway love to learn python and machin learning.

# %%
import string
transform_text('I always loved to learn Python and Machine Learning.')
# Out:
# 'i alway love to learn python and machin learning.'

# %%
df['text'][0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
import string

df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words                                      num_sentences  \
# 0         24  [Go until jurong point, crazy.., Available onl...
# 1          8                   [Ok lar..., Joking wif u oni...]
# 2         37  [Free entry in 2 a wkly comp to win FA Cup fin...
# 3         13  [U dun say so early hor... U c already then sa...
# 4         15  [Nah I don't think he goes to usf, he lives ar...
#
#                                     transformed_text
# 0  go until jurong point, crazy.. avail onli in b...
# 1                        ok lar... joke wif u oni...
# 2  free entri in 2 a wkli comp to win fa cup fina...
# 3  u dun say so earli hor... u c alreadi then say...
# 4  nah i don't think he goe to usf, he live aroun...

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
span_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep = " "))

# %%
plt.figure(figsize=(12,6))
plt.imshow(span_wc)

# %%
ham_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep = " "))

# %%
plt.figure(figsize=(12,6))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words                                      num_sentences  \
# 0         24  [Go until jurong point, crazy.., Available onl...
# 1          8                   [Ok lar..., Joking wif u oni...]
# 2         37  [Free entry in 2 a wkly comp to win FA Cup fin...
# 3         13  [U dun say so early hor... U c already then sa...
# 4         15  [Nah I don't think he goes to usf, he lives ar...
#
#                                     transformed_text
# 0  go until jurong point, crazy.. avail onli in b...
# 1                        ok lar... joke wif u oni...
# 2  free entri in 2 a wkli comp to win fa cup fina...
# 3  u dun say so earli hor... u c alreadi then say...
# 4  nah i don't think he goe to usf, he live aroun...

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 15464

# %%
from collections import Counter
import pandas as pd
import seaborn as sns

# Count occurrences of each word in spam_corpus
word_counts = Counter(spam_corpus)

# Convert the Counter object to a DataFrame
word_counts_df = pd.DataFrame(word_counts.items(), columns=['Word', 'Count'])

# Sort the DataFrame by count in descending order
word_counts_df = word_counts_df.sort_values(by='Count', ascending=False)

# Plot the bar plot using seaborn
sns.barplot(x='Word', y='Count', data=word_counts_df.head(30))
# Out:
# <Axes: xlabel='Word', ylabel='Count'>

# %%
ham_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 15464

# %%
from collections import Counter
import pandas as pd
import seaborn as sns

# Count occurrences of each word in spam_corpus
word_counts = Counter(ham_corpus)

# Convert the Counter object to a DataFrame
word_counts_df = pd.DataFrame(word_counts.items(), columns=['Word', 'Count'])

# Sort the DataFrame by count in descending order
word_counts_df = word_counts_df.sort_values(by='Count', ascending=False)

# Plot the bar plot using seaborn
sns.barplot(x='Word', y='Count', data=word_counts_df.head(30))
# Out:
# <Axes: xlabel='Word', ylabel='Count'>

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words                                      num_sentences  \
# 0         24  [Go until jurong point, crazy.., Available onl...
# 1          8                   [Ok lar..., Joking wif u oni...]
# 2         37  [Free entry in 2 a wkly comp to win FA Cup fin...
# 3         13  [U dun say so early hor... U c already then sa...
# 4         15  [Nah I don't think he goes to usf, he lives ar...
#
#                                     transformed_text
# 0  go until jurong point, crazy.. avail onli in b...
# 1                        ok lar... joke wif u oni...
# 2  free entri in 2 a wkli comp to win fa cup fina...
# 3  u dun say so earli hor... u c alreadi then say...
# 4  nah i don't think he goe to usf, he live aroun...

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
tfidf = TfidfVectorizer()
cv = CountVectorizer()

# %%
X = cv.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 8218)

# %%
y = df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.9061895551257253
# [[811  85]
#  [ 12 126]]
# 0.5971563981042654

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9738878143133463
# [[878  18]
#  [  9 129]]
# 0.8775510204081632

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.97678916827853
# [[894   2]
#  [ 22 116]]
# 0.9830508474576272

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\100956383\appdata\local\anaconda3\lib\site-packages (from xgboost) (1.11.4)

# %%
# !pip install ExtraTreesClassifier
from sklearn.ensemble import ExtraTreesClassifier
# Out:
# ERROR: Could not find a version that satisfies the requirement ExtraTreesClassifier (from versions: none)
# ERROR: No matching distribution found for ExtraTreesClassifier

# %%
svc = SVC(kernel= 'sigmoid',gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear',penalty='l1')
rfc = RandomForestClassifier(n_estimators=50,random_state=2)
abc = AdaBoostClassifier(n_estimators=50,random_state=2)
bc = BaggingClassifier(n_estimators=50,random_state=2)
etc = ExtraTreesClassifier(n_estimators=50,random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc,
    'NB' : mnb,
    'DT' : dtc,
    'LR' : lrc,
    'RF' : rfc,
    'AdaBoost' : abc,
    'BgC' : bc,
    'ETC' : etc,
    'GBDT' : gbdt,
    'xgb': xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)

    return accuracy,precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.8413926499032882, 0.3898305084745763)

# %%
accuracy_scores_list = []
precision_scores_list = []

for name,clf in clfs.items():

    current_accuracy,current_precision = train_classifier(clf,X_train,y_train,X_test,y_test)

    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)

    accuracy_scores_list.append(current_accuracy)
    precision_scores_list.append(current_precision)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 6
#       2 precision_scores_list = []
#       4 for name,clf in clfs.items():
# ----> 6     current_accuracy,current_precision = train_classifier(clf,X_train,y_train,X_test,y_test)
#       8     print("For ",name)
#       9     print("Accuracy - ",current_accuracy)
#
# Cell In[91], line 4, in train_classifier(clf, X_train, y_train, X_test, y_test)
#       2 clf.fit(X_train,y_train)
#       3 y_pred = clf.predict(X_test)
# ----> 4 accuracy = accuracy_score(y_test,y_pred)
#       5 precision = precision_score(y_test,y_pred)
#       7 return accuracy,precision
#
# TypeError: 'list' object is not callable
